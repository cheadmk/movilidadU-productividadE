# %% [markdown]
# <a href="https://colab.research.google.com/github/cheadmk/movilidadU-productividadE/blob/main/S5_ladb_mobility_economy_project_student_FINAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ¡Hola! 😊
#
# Mi nombre es **Alejandro Castellanos** y hoy tengo el placer de ser el revisor de tu proyecto.
#
# Voy a revisar todo tu código con detalle, buscando tanto los puntos fuertes como aquellos en los que podrías mejorar. Te dejaré comentarios a lo largo del notebook, destacando lo que has hecho bien y sugiriendo ajustes donde sea necesario. Si encuentro algún error, no te preocupes, te lo haré saber de forma clara y te daré información útil para que puedas corregirlo en la próxima iteración. Si en algún punto tienes comentarios, siéntete libre de dejarlos también.
#
#
# Encontrarás mis comentarios específicos dentro de cajas verdes, amarillas o rojas, es muy importante que no muevas, modifiques o borres mis comentarios, con el fin de tener un seguimiento adecuado de tu proceso:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si todo está perfecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class=“tocSkip”></a>
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma:
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class=“tocSkip”></a>
# </div>
#
# A continuación te dejaré un comentario general con mi valoración del proyecto. **¡Mi objetivo es que sigas aprendiendo y mejorando con cada paso!**

# %% [markdown]
# ----

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario General del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Hiciste un trabajo ordenado y bien encaminado en esta primera iteración: se nota que comenzaste con una revisión adecuada de los datos, organizaste las columnas de forma consistente y construiste una tabla consolidada útil para el análisis, además de presentar visualizaciones y un cierre que conecta bien con el objetivo del proyecto.
#
#
# Como recomendación para futuros proyectos, te conviene cuidar mejor la consistencia de los tipos de datos, especialmente en variables numéricas, y agregar validaciones breves después de pasos importantes como el filtrado y la unión de tablas, para confirmar que todo quedó como esperabas. También sería bueno ajustar algunas visualizaciones para que la comparación entre variables sea más clara y, en las conclusiones, respaldar mejor las afirmaciones con una medida cuantitativa que sustente la relación que describes.
#
# Vas por una buena ruta, y con estos ajustes tu análisis puede quedar mucho más sólido y confiable.
#
# Éxitos en tu próximo Sprint 🚀
#
# *Estado del Proyecto:* **Aprobado**
#
# </div>

# %% [markdown]
# -----

# %% [markdown]
# ## Introducción
#
# Como analista de datos, tu objetivo es **evaluar cómo la movilidad urbana se relaciona con la productividad económica en las principales ciudades latinoamericanas**.
# Para ello trabajarás con datos reales de TomTom Traffic Index y OECD Cities, que deberás limpiar, combinar y analizar para identificar en qué ciudades conviene invertir en infraestructura de transporte.

# %% [markdown]
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de ambos datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯Objetivo:**
# Importar las librerías necesarias, cargar los archivos CSV en DataFrames y realizar una revisión preliminar para entender su contenido.
#
# **Instrucciones:**
# - Importa las librerías `pandas`, `numpy`, `seaborn` y `matplotlib.pyplot`.
# - Carga los archivos usando `pd.read_csv()`:
#   - `'/datasets/tomtom_traffic.csv'`
#   - `/datasets/oecd_city_economy.csv` `.
# - Guarda los DataFrames en las variables `traffic` y `eco`.
# - Muestra las primeras 5 filas de cada DataFrame.

# %%
# importar librerías
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
traffic = pd.read_csv('datasets/tomtom_traffic.csv')
eco = pd.read_csv('datasets/oecd_city_economy.csv') #completa el código

# %%
# mostrar las primeras 5 filas de traffic
traffic.head()
# Out:
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
# 3     ARE  abu-dhabi  2025-01-13 01:46:30.001        8.2               2.0
# 4     ARE  abu-dhabi  2025-01-13 00:01:30.000        1.1               1.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
# 3              4.1        2.0                  2.0  2025-01-06 01:46:30.000
# 4              0.2        1.0                  1.0  2025-01-06 00:01:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232
# 3                    7.723808                        7.899046  -0.175238
# 4                    8.336363                        8.604379  -0.268016

# %%
# mostrar las primeras 5 filas de eco
eco.head()
# Out:
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
# 3  2023        brasilia     Brazil       15.999,00           8.3%
# 4  2023        salvador     Brazil        8.761,00          13.1%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60
# 3         13,50           4,70
# 4         16,00           3,90

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Cargaste correctamente las librerías clave y los datasets **traffic** y **eco**, y además mostraste una vista rápida con `.head()` que permite confirmar de inmediato que las tablas se leyeron bien y que las columnas esperadas están presentes.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Explorar, limpiar y preparar los datos
#
# Antes de combinar los datasets, inspecciona su estructura, tipos de datos, columnas y valores faltantes.
# Anota las columnas que necesiten limpieza y luego estandariza los nombres de columnas.
#
# ### 2.1 Explorar la estructura y tipos de datos
#
# **🎯Objetivo:**
# Identificar columnas con tipos incorrectos, distribución y nulos, anotar las columnas que requieren conversión.
#
# **Instrucciones:**
#
# - Usa `.info()` para conocer la estructura de ambos DataFrames.
# - Muestra los primeros 3 renglones de cada DF.
# - Identifica si los detalles de cada DF estan bien o si requieren correcciones y escribe tus conclusiones en el bloque Markdown.
#   - ¿Hay columnas que requieren conversión?¿ Cuáles son? ¿Que tipo de dato tienen y cuáles deberían de tener?
#   - ¿Hay datos ausentes en alguna columna?

# %%
# Examinar la estructura de traffic
traffic.info()
traffic.head(3)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Country                         1004464 non-null  str
#  1   City                            1004464 non-null  str
#  2   UpdateTimeUTC                   1004464 non-null  str
#  3   JamsDelay                       1004464 non-null  float64
#  4   TrafficIndexLive                1004464 non-null  float64
#  5   JamsLengthInKms                 1004464 non-null  float64
#  6   JamsCount                       1004464 non-null  float64
#  7   TrafficIndexWeekAgo             1004464 non-null  float64
#  8   UpdateTimeUTCWeekAgo            1004464 non-null  str
#  9   TravelTimeLivePer10KmsMins      1004464 non-null  float64
#  10  TravelTimeHistoricPer10KmsMins  1004464 non-null  float64
#  11  MinsDelay                       1004464 non-null  float64
# dtypes: float64(8), str(4)
# memory usage: 92.0 MB
#   Country       City            UpdateTimeUTC  JamsDelay  TrafficIndexLive  \
# 0     ARE  abu-dhabi  2025-01-13 04:01:30.001      650.7              36.0
# 1     ARE  abu-dhabi  2025-01-13 03:46:00.000      540.4              30.0
# 2     ARE  abu-dhabi  2025-01-13 02:46:30.000       71.8               7.0
#
#    JamsLengthInKms  JamsCount  TrafficIndexWeekAgo     UpdateTimeUTCWeekAgo  \
# 0            109.1      162.0                 30.0  2025-01-06 04:01:30.000
# 1            101.4      136.0                 27.0  2025-01-06 03:46:30.001
# 2             18.9       23.0                  6.0  2025-01-06 02:46:30.000
#
#    TravelTimeLivePer10KmsMins  TravelTimeHistoricPer10KmsMins  MinsDelay
# 0                   11.614767                       10.265330   1.349437
# 1                   11.003180                       10.031544   0.971635
# 2                    8.196278                        8.196510  -0.000232

# %% [markdown]
# En la estructura del DF traffic, se observa que:
# - Las columnas `UpdateTimeUTC` y `UpdateTimeUTCWeekAgo` son de tipo ...
# - objeto...
# ¿Hay columnas que requieren conversión? Si
# ¿Cuáles son? Country, City, UpdateTimeUTC, UpdateTimeUTCWeekAgo, JamsCount
# ¿Que tipo de dato tienen y cuáles deberían de tener? Country, City son objetos pero deberían tener string. UpdateTimeUTC, UpdateTimeUTCWeekAgo son objetos pero deberían tener datetime. JamsCount es float64 pero debería tener integer.
# ¿Hay datos ausentes en alguna columna? No, ninguno (not-null = 1004464)

# %%
# Examinar la estructura de eco
eco.info()
eco.head(3)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   City             30 non-null     str
#  2   Country          30 non-null     str
#  3   City GDP/capita  30 non-null     str
#  4   Unemployment %   30 non-null     str
#  5   PM2.5 (μg/m³)    30 non-null     str
#  6   Population (M)   30 non-null     str
# dtypes: int64(1), str(6)
# memory usage: 1.8 KB
#    Year            City    Country City GDP/capita Unemployment %  \
# 0  2023    buenos-aires  Argentina       15.782,00           6.2%
# 1  2023       sao-paulo     Brazil       14.475,00           9.1%
# 2  2023  rio-de-janeiro     Brazil       13.142,00           9.8%
#
#   PM2.5 (μg/m³) Population (M)
# 0          15,2          15,30
# 1         29,50          22,50
# 2         19,10          13,60

# %% [markdown]
# En la estructura del DF eco, se observa que:
# - Las columnas `City GDP/capita`, `Unemployment %`, ...
# - son de tipo objeto...
# ¿Hay columnas que requieren conversión? Si
# ¿Cuáles son? Year, City, Country, City GDP/capita, Unemployment %, PM2.5 (μg/m³) y Population (M)
# ¿Que tipo de dato tienen y cuáles deberían de tener? Year es int64 pero debería ser int pero limitado a 4 digitos. City y Country son objetos pero deberían tener string. City GDP/capita, Unemployment, PM2.5 (μg/m³) y Population (M) son objetos pero deberían tener float.
# ¿Hay datos ausentes en alguna columna? No, ninguno (not-null = 30)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Revisaste bien la estructura con `.info()` y complementaste con una muestra pequeña de filas, lo que ayuda a entender tipos de datos, nulos y forma general antes de aplicar limpieza o transformaciones.
#
# </div>

# %% [markdown]
# ### 2.2 Renombrar columnas
#
# **🎯Objetivo:**
# Estandarizar los nombres de columnas para evitar errores y facilitar la unión de los datasets.
#
# **Instrucciones:**
#
# - Cambia los nombres de las columnas para que tengan el formato `snake_case`.
#     - `Country` → `country`
#     - `UpdateTimeUTC` → `update_time_utc`
# - Verifica que los cambios se hayan aplicado correctamente usando `.columns`.

# %%
# Estandarizar los nombres de las columnas de traffic
traffic.columns = ['country', 'city', 'update_time_utc', 'jams_delay',
                   'traffic_index_live', 'jams_length_kms', 'jams_count',
                   'traffic_index_week_ago', 'update_time_utc_week_ago',
                   'travel_time_live_per_10kms_mins', 'travel_time_hist_per_10kms_mins',
                   'mins_delay'] #tu código aquí

# verificar cambios
traffic.columns
# Out:
# Index(['country', 'city', 'update_time_utc', 'jams_delay',
#        'traffic_index_live', 'jams_length_kms', 'jams_count',
#        'traffic_index_week_ago', 'update_time_utc_week_ago',
#        'travel_time_live_per_10kms_mins', 'travel_time_hist_per_10kms_mins',
#        'mins_delay'],
#       dtype='str')

# %%
# Estandarizar los nombres de las columnas de eco
eco.columns = ['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
              'pm25', 'population_m'] #tu código aquí

# verificar cambios
eco.columns
# Out:
# Index(['year', 'city', 'country', 'city_gdp_capita', 'unemployment_pct',
#        'pm25', 'population_m'],
#       dtype='str')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Estandarizaste los nombres de columnas en **traffic** y **eco** con un esquema consistente en snake_case, lo cual facilita el resto del flujo y reduce errores en filtros, `groupby` y `merge`.
#
# </div>

# %% [markdown]
# ### 2.3 Corregir formatos numéricos y de fecha
#
# **🎯Objetivo:**
# Asegurar que las columnas de fechas y valores numéricos estén en formatos correctos para permitir análisis, cálculos y comparaciones precisas.
#
# **Instrucciones:**
#
# - Convierte las columnas de fecha de `traffic` a formato `datetime`. Haz el cambio a prueba de errores.
# - En el dataset `eco`, limpia los valores numéricos:
#     - En `city_gdp_capita`: elimina separadores de miles (`.`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `unemployment_pct`: elimina el símbolo de porcentaje (`%`) y reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
#     - En `population_m`: reemplaza las comas (`','`) por puntos (`'.'`) antes de convertir a tipo `float`.
# - Finalmente, crea una nueva columna llamada `population` multiplicando `population_m` por 1,000,000 para obtener la población total.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# para eliminar símbolos, puedes reemplazarlos por un texto vacío.

# %%
# Convertir las columnas de traffic a tipo fecha con pd.to_datetime()
traffic['update_time_utc'] = pd.to_datetime(traffic['update_time_utc'], errors='coerce') #tu código aquí
traffic['update_time_utc_week_ago'] = pd.to_datetime(traffic['update_time_utc_week_ago'], errors='coerce') #tu código aquí

# verificar el cambio
traffic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1004464 entries, 0 to 1004463
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   country                          1004464 non-null  str
#  1   city                             1004464 non-null  str
#  2   update_time_utc                  1004464 non-null  datetime64[us]
#  3   jams_delay                       1004464 non-null  float64
#  4   traffic_index_live               1004464 non-null  float64
#  5   jams_length_kms                  1004464 non-null  float64
#  6   jams_count                       1004464 non-null  float64
#  7   traffic_index_week_ago           1004464 non-null  float64
#  8   update_time_utc_week_ago         1004464 non-null  datetime64[us]
#  9   travel_time_live_per_10kms_mins  1004464 non-null  float64
#  10  travel_time_hist_per_10kms_mins  1004464 non-null  float64
#  11  mins_delay                       1004464 non-null  float64
# dtypes: datetime64[us](2), float64(8), str(2)
# memory usage: 92.0 MB

# %%
# Limpia separadores y convierte columnas numéricas en eco
eco['city_gdp_capita'] = eco['city_gdp_capita'].astype(str).str.replace('.', '').str.replace(',', '.').astype(float)
eco['unemployment_pct'] = eco['unemployment_pct'].astype(str).str.replace('%', '').str.replace(',', '.').astype(float)
eco['population_m'] = eco['population_m'].astype(str).str.replace(',', '.').astype(float)
eco['pm25'] = eco['pm25'].astype(str).str.replace(',', '.').astype(float)

# Calcula la población total en unidades absolutas (Multiplica * 1000000)
eco['population'] = eco['population_m']*1000000

# verificar el cambio
eco.info()
eco.head(3)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              30 non-null     int64
#  1   city              30 non-null     str
#  2   country           30 non-null     str
#  3   city_gdp_capita   30 non-null     float64
#  4   unemployment_pct  30 non-null     float64
#  5   pm25              30 non-null     float64
#  6   population_m      30 non-null     float64
#  7   population        30 non-null     float64
# dtypes: float64(5), int64(1), str(2)
# memory usage: 2.0 KB
#    year            city    country  city_gdp_capita  unemployment_pct  pm25  \
# 0  2023    buenos-aires  Argentina          15782.0               6.2  15.2
# 1  2023       sao-paulo     Brazil          14475.0               9.1  29.5
# 2  2023  rio-de-janeiro     Brazil          13142.0               9.8  19.1
#
#    population_m  population
# 0          15.3  15300000.0
# 1          22.5  22500000.0
# 2          13.6  13600000.0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Buen trabajo, los datos has sido convertidos correctamente.
#
# Ten en cuenta que la columna *pm25* tiene información numérica, pero la dejaste como un `object` (texto), ya que su separador es una coma `(,)`. Debes asegurarte que todas tus columnas tengan el tipo adecuado, para evitar problemas o errores en el análisis
#
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Extraer año y filtrar
#
# Extraer el año permite filtrar la información y trabajar solo con el período más reciente y relevante.
#
# ### 3.1 Extraer columna año y filtrar 2024
#
# **🎯Objetivo**
# Identificar el año de cada registro y mantener solo los registros del 2024.
#
# **Intrucciones**
#
# - Como el DataFrame `traffic` no tiene una columna de año, utiliza el atributo `.dt.year` sobre su columna de fecha para crear una nueva columna llamada `year`.
# - Filtra las filas donde el año sea **2024**.
# - Utiliza `.copy()` para crear dos nuevos DataFrames (`traffic_2024` y `eco_2024`) para evitar modificar el dataset original.

# %%
# Extraer el año de las fechas en update_time_utc
traffic['year'] = traffic['update_time_utc'].dt.year

# Verificar cambio
traffic.head(3)
# Out:
#   country       city         update_time_utc  jams_delay  traffic_index_live  \
# 0     ARE  abu-dhabi 2025-01-13 04:01:30.001       650.7                36.0
# 1     ARE  abu-dhabi 2025-01-13 03:46:00.000       540.4                30.0
# 2     ARE  abu-dhabi 2025-01-13 02:46:30.000        71.8                 7.0
#
#    jams_length_kms  jams_count  traffic_index_week_ago  \
# 0            109.1       162.0                    30.0
# 1            101.4       136.0                    27.0
# 2             18.9        23.0                     6.0
#
#   update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 0  2025-01-06 04:01:30.000                        11.614767
# 1  2025-01-06 03:46:30.001                        11.003180
# 2  2025-01-06 02:46:30.000                         8.196278
#
#    travel_time_hist_per_10kms_mins  mins_delay  year
# 0                        10.265330    1.349437  2025
# 1                        10.031544    0.971635  2025
# 2                         8.196510   -0.000232  2025

# %%
# Filtra los registros del año 2024

traffic_2024 = traffic[traffic['year'] == 2024].copy()
eco_2024 = eco[eco['year'] == 2024].copy()


# Revisar dataframes nuevos
display(traffic_2024.head())
display(eco_2024.head())


# Validación rápida posterior al filtrado
print("Años en traffic_2024:", traffic_2024['year'].unique())
print("Filas traffic_2024:", traffic_2024.shape[0])
print("Años en eco_2024:", eco_2024['year'].unique())
print("Filas eco_2024:", eco_2024.shape[0])
# Out:
#     country       city         update_time_utc  jams_delay  \
# 302     ARE  abu-dhabi 2024-12-31 23:01:30.000        12.9
# 303     ARE  abu-dhabi 2024-12-31 22:01:30.000       136.0
# 304     ARE  abu-dhabi 2024-12-31 21:16:30.000       455.2
# 305     ARE  abu-dhabi 2024-12-31 20:01:00.001       399.4
# 306     ARE  abu-dhabi 2024-12-31 19:46:00.000       366.4
#
#      traffic_index_live  jams_length_kms  jams_count  traffic_index_week_ago  \
# 302                 5.0              2.5         5.0                     2.0
# 303                21.0             20.6        32.0                     3.0
# 304                31.0             40.4        72.0                     4.0
# 305                27.0             38.0        75.0                     6.0
# 306                28.0             39.8        82.0                     9.0
#
#     update_time_utc_week_ago  travel_time_live_per_10kms_mins  \
# 302  2024-12-24 23:01:30.001                         8.560399
# 303  2024-12-24 22:01:30.000                        10.355732
# 304  2024-12-24 21:01:30.000                        11.456878
# 305  2024-12-24 20:01:30.001                        11.670062
# 306  2024-12-24 19:01:00.000                        11.686322
#
#      travel_time_hist_per_10kms_mins  mins_delay  year
# 302                         8.519634    0.040765  2024
# 303                         9.049445    1.306286  2024
# 304                         9.305174    2.151704  2024
# 305                         9.952811    1.717252  2024
# 306                        10.008469    1.677853  2024
#     year            city    country  city_gdp_capita  unemployment_pct  pm25  \
# 15  2024    buenos-aires  Argentina          18117.0               7.2  14.5
# 16  2024       sao-paulo     Brazil          14703.0               8.5  28.0
# 17  2024  rio-de-janeiro     Brazil          13349.0               9.2  18.4
# 18  2024        brasilia     Brazil          16251.0               7.8  12.8
# 19  2024        salvador     Brazil           8899.0              12.4  15.2
#
#     population_m  population
# 15          15.4  15400000.0
# 16          22.6  22600000.0
# 17          13.7  13700000.0
# 18           4.8   4800000.0
# 19           3.9   3900000.0
# Años en traffic_2024: [2024]
# Filas traffic_2024: 886779
# Años en eco_2024: [2024]
# Filas eco_2024: 15

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# La extracción de *year* desde *update_time_utc* y el filtrado a 2024 con `.copy()` están bien planteados, pero faltó una verificación breve de años únicos o conteo de filas para confirmar que el recorte realmente quedó solo en 2024.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Analizar y resumir datos de movilidad
#
# Como el dataset de tráfico contiene **múltiples registros por ciudad**. En esta parte, calcularás los promedios anuales por ciudad para simplificar el análisis y obtener una visión más clara de las tendencias generales.
#
# ### 4.1 Calcular promedios de tráfico por ciudad
#
# **🎯Objetivo:**
# Obtener una vista consolidada del tráfico promedio por ciudad y año, para analizar patrones generales sin depender de datos diarios.
#
# **Instrucciones**
#
# - Agrupa los datos por `city`, `country` y `year`.
# - Calcula el promedio **solo de las métricas de tráfico más relevantes**: como `jams_delay`, `traffic_index_live`, `jams_length_kms`, `jams_count`, `mins_delay`, y tiempos de viaje (`travel_time_live_per_10kms_mins` y `travel_time_hist_per_10kms_mins`).
# - Guarda el resultado como `traffic_city_year_2024`, mantén las columnas como variables (no índices).

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa ".agg()" para aplicar funciones de promedio. Al final, reinicia el índice para mantener las columnas de la agrupación como variables (no índices).

# %%
# Calcular los  promedios de trafico por ciudad, país y año
# tu código aqui
traffic_city_year_2024 = traffic_2024.groupby(['city', 'country', 'year']).agg({
    'jams_delay': 'mean',
    'traffic_index_live': 'mean',
    'jams_length_kms': 'mean',
    'jams_count': 'mean',
    'mins_delay': 'mean',
    'travel_time_live_per_10kms_mins': 'mean',
    'travel_time_hist_per_10kms_mins': 'mean'
}).reset_index()

# Mostrar resultado
traffic_city_year_2024.head()
traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)
# Out:
#             city country  year   jams_delay  traffic_index_live  \
# 221  mexico-city     MEX  2024  2833.057892           34.218190
# 352        tokyo     JPN  2024  2152.574357           36.805059
# 246     new-york     USA  2024  2133.400000           28.210388
# 200       london     GBR  2024  2050.703662           29.230166
# 211       manila     PHL  2024  1741.493381           66.129402
# ..           ...     ...   ...          ...                 ...
# 111      dunedin     NZL  2024     4.651175           15.430809
# 363      uppsala     SWE  2024     4.194486           13.939168
# 123     fujairah     ARE  2024     4.025959           10.907719
# 12        almere     NLD  2024     3.633523            6.290478
# 117      el-paso     USA  2024     0.299024            2.340435
#
#      jams_length_kms  jams_count  mins_delay  travel_time_live_per_10kms_mins  \
# 221       389.239265  594.969392    1.855542                        21.809092
# 352       373.069734  518.809420    0.698152                        22.443778
# 246       398.227892  544.474902    1.396351                        18.505043
# 200       287.632868  471.795554    1.325160                        17.714139
# 211       246.858082  341.881205    2.469894                        27.134629
# ..               ...         ...         ...                              ...
# 111         0.712315    1.591384    0.633294                        16.226009
# 363         0.656368    1.349672    0.501802                        15.746717
# 123         0.731910    1.373006    0.194951                        11.662590
# 12          0.506362    1.064063   -0.017544                         9.467150
# 117         0.031114    0.078118   -0.250676                        10.690269
#
#      travel_time_hist_per_10kms_mins
# 221                        19.953550
# 352                        21.745626
# 246                        17.108691
# 200                        16.388979
# 211                        24.664734
# ..                               ...
# 111                        15.592715
# 363                        15.244916
# 123                        11.467639
# 12                          9.484694
# 117                        10.940945
#
# [387 rows x 10 columns]

# %% [markdown]
# ### 🧠 **Momento de reflexión**
#
# ¡Excelente trabajo hasta aquí!
#
# Ahora que ya tienes los promedios anuales por ciudad, es momento de **observarlos** con atención.
#
# Piensa:
#
# - ¿Cuál crees que tiene el mayor tiempo promedio de tráfico?
# - ¿Será una ciudad de **Europa**, de **Latinoamérica** o de **otra región** del mundo?
#
# Para descubrirlo, ejecuta esta línea de código:
#
# `traffic_city_year_2024.sort_values(["jams_delay"], ascending=False)`
#
#
# 🔍 Observa qué ciudad aparece en los primeros lugares.
#
# ¿Te sorprenden los resultados? , ¿Coinciden con lo que imaginabas?

# %%
# tu código aquí
print(traffic_2024['year'].unique())
print(eco_2024['year'].unique())
print(traffic_2024.shape)
print(eco_2024.shape)
# Out:
# [2024]
# [2024]
# (886779, 13)
# (15, 8)

# %% [markdown]
# La ciudad con el mayor tiempo promedio de tráfico es Mexico City. El resultado coincide con lo esperado debido a que esta ciudad es reconocida por presentar altos niveles de congestión urbana. No obstante, el análisis actual únicamente permite identificar el patrón observado en los datos; establecer las causas de esta congestión requeriría información adicional sobre población, infraestructura vial y movilidad urbana.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# La agregación por *city*, *country* y *year* está correcta, promediaste métricas clave y cerraste con `reset_index()`, logrando una tabla consolidada por ciudad-año que queda lista para unir con economía.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Unir movilidad y economía
#
# Combinar datasets te permite analizar cómo se relacionan los indicadores económicos con los de movilidad.
#
# ### 5.1 Unir tráfico (tabla principal) con indicadores económicos
#
# **🎯Objetivo:**
# Combinar la información de tráfico y economía en un solo DataFrame para analizar cómo las condiciones económicas se relacionan con la movilidad urbana.
#
# **Instrucciones**
# - Selecciona solo las **columnas relevantes** de cada dataset (por ejemplo, variables clave de tráfico y de economía).
# - Usa `.copy()` al crear subconjuntos para evitar modificar el dataset original.
# - Une ambos DataFrames y define como **claves de unión** a `city` y `year`.
# - Mantén solo las ciudades y años presentes en ambos datasets.
# - Guarda el resultado en una nueva variable llamada `merged` y muestra las primeras 5 filas.

# %% [markdown]
# <details>
# <summary>Haz clic para ver la pista</summary>
# Aplica una unión de tipo "inner" para mantener las ciudades y años presentes en ambos datasets.

# %%
# Seleccionar columnas clave de tráfico y economía
left_cols = ['city','country','year','jams_delay','traffic_index_live',
             'jams_length_kms','jams_count','mins_delay',
             'travel_time_live_per_10kms_mins','travel_time_hist_per_10kms_mins']

right_cols = ['city','year','city_gdp_capita','unemployment_pct','pm25','population']

# Usar .copy() para crear los dos nuevos datasets reducidos
traffic_2024_small = traffic_city_year_2024[left_cols].copy()
eco_2024_small = eco_2024[right_cols].copy()

# Unir datasets
merged = traffic_2024_small.merge(eco_2024_small, on=['city', 'year'], how='inner') # tu código aquí

# Mostrar las primeras 5 filas
# tu código aquí
merged.head()

# Validaciones posteriores al merge
print("Dimensiones del dataset unido:", merged.shape)
print("Filas duplicadas:", merged.duplicated().sum())
# Out:
# Dimensiones del dataset unido: (15, 14)
# Filas duplicadas: 0

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Seleccionaste columnas relevantes, aplicaste `.copy()` y realizaste el `merge` con `how='inner'` usando *city* y *year*, lo cual es coherente con el objetivo. Como mejora, conviene añadir una validación rápida del `.shape` y revisar duplicados para confirmar que la unión no multiplicó filas.
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Visualización y análisis de relaciones
#
# Ahora que tienes un dataset limpio y unificado, es momento de **visualizar patrones**.
# Los gráficos te ayudarán a entender cómo se relacionan las variables económicas con las de movilidad urbana.
#
# ### 6.1 Visualizar relaciones entre economía y tráfico
#
# **🎯Objetivo:**
# Analizar visualmente la distribución y la relación entre indicadores de tráfico y economía en 2024, para identificar posibles patrones o tendencias generales entre ambas variables.
#
# **Instrucciones**
# - Usa las librerías `seaborn` y `matplotlib.pyplot` para generar los gráficos.
# - Visualiza la distribución del **tráfico** (`jams_delay`) mediante:
#     - **Boxplot** → para observar la media, mediana y detectar valores atípicos.
# - Visualiza la distribución de la **economía** (`city_gdp_capita`) mediante:
#     - **Histograma** → para analizar la forma de la distribución y el valor promedio del PIB per cápita.
# - Finalmente, **compara ambas variables**, para observar si existe alguna relación entre ellas, haciendo un solo gráfico de barras donde aparezcan ambos indicadores.
# - Recuerda agregar título y etiquetas a los ejes de tus gráficos.
# - Observa y comenta los patrones, valores extremos o posibles relaciones que identifiques.

# %% [markdown]
# **Tip:** Dentro de los parentesis del boxplot, agrega `showmeans=True` para ver la media en el gráfico.

# %%
# Crear boxplot para observar el comportamiento de los minutos de congestion JamsDelay
# crea tu gráfico
plt.figure(figsize=(5, 8))
sns.boxplot(y=merged['jams_delay'], showmeans=True)

# Calcular estadísticas con merged['jams_delay'].describe()

# **Mínimo:** 50 minutos
# **Q1 (Primer cuartil):** 107 minutos
# **Mediana (Q2):** 263 minutos
# **Promedio:** 630 minutos
# **Q3 (Tercer cuartil):** 841 minutos
# **Outliers:** Valores superiores a 1,942 minutos

# La distribución presenta una **asimetría positiva** marcada, ya que el promedio (630) es considerablemente mayor que la mediana (263)
# El **50% de las ciudades** experimentan entre 107 y 841 minutos de retraso diario
# Existen **valores atípicos significativos** (>1,942 min) que corresponden a ciudades con congestión extrema
# La **variabilidad es alta**, indicando diferencias sustanciales en los niveles de tráfico entre ciudades

# **Fórmula para identificar outliers:**
# Identificar outliers (valores > Q3 + 1.5*IQR)
# Límite superior = Q3 + 1.5 × (Q3 - Q1)
# Límite superior = 841 + 1.5 × (841 - 107) = 1,942 minutos

# obtener promedio para mostrarlo en título
mean_value = merged['jams_delay'].mean()
plt.title(f'Boxplot de JamsDelay (2024)\nPromedio: {mean_value:.2f}')
plt.ylabel('Minutos de retraso')
plt.show()

# %%
# Crear histograma para ver la distribución de la economía (city_gdp_capita)
plt.figure(figsize=(10, 6))

# Crear el histograma
sns.histplot(x=merged['city_gdp_capita'], bins=10, edgecolor='black')

# Añadir títulos y etiquetas
plt.title('Distribución del PIB per cápita')
plt.xlabel('PIB per cápita (USD)')
plt.ylabel('Frecuencia')

# Mostrar el gráfico
plt.show()

# %%
# Gráfico con doble eje Y para comparar variables en diferentes escalas
fig, ax1 = plt.subplots(figsize=(15, 8))

ax1.bar(merged['city'], merged['jams_delay'])
ax1.set_xlabel('Ciudad')
ax1.set_ylabel('Jams Delay')

ax2 = ax1.twinx()
ax2.plot(merged['city'], merged['city_gdp_capita'], marker='o')
ax2.set_ylabel('PIB per cápita')

plt.title('Comparación de Tráfico y PIB per cápita por Ciudad')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Tip:** Antes del `plt.show()` agrega el código `plt.xticks(rotation=90)` para rotar las etiquetas del eje X en 90 grados.

# %% [markdown]
# ### 🧠 **Reflexiona**
# Excelente trabajo llegando a esta etapa del análisis. Antes de avanzar, revisa tus gráficos, tómate un momento para pensar:
#
# * ¿Las ciudades con mayor PIB per cápita también presentan más congestión?
#
# * ¿O sucede lo contrario, o no existe una relación clara?

# %% [markdown]
# Escribe tus comentarios:
#
# Para complementar el análisis visual, se recomienda calcular una correlación cuantitativa entre `city_gdp_capita` y `jams_delay` utilizando el coeficiente de Pearson.
#
# Ejemplo:
#
# corr = merged['city_gdp_capita'].corr(merged['jams_delay'])
# print(corr)
#
# Interpretación:
#
# - Correlación cercana a 1: relación positiva fuerte.
# - Correlación cercana a -1: relación negativa fuerte.
# - Correlación cercana a 0: ausencia de relación lineal significativa.
#
# Con base en los gráficos observados, parece existir una relación débil o moderada entre el PIB per cápita y la congestión. Sin embargo, no es posible afirmar una correlación significativa sin presentar explícitamente el valor del coeficiente de correlación.
#
# Además, ciudades como Bogotá, Buenos Aires y Brasília sugieren que variables adicionales como infraestructura vial, transporte público, densidad poblacional y planificación urbana influyen de manera importante en los niveles de congestión.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Los gráficos cubren lo solicitado y están bien etiquetados, incluyendo media en el boxplot y rotación de etiquetas en barras. Para mejorar lectura y comparación, ayudaría usar un enfoque consistente (por ejemplo `sns.boxplot` / `sns.histplot`) y como recomendación para la última gráfica, al mezclar variables con escalas tan distintas el mensaje puede volverse confuso, podrías usar gráficos separados o normalizar los valores. Otra opción sería configurar dos ejes Y distintos, lo cual permita presentar la información de manera más clara. Te comparto una página donde explican como hacer esta configuración: [Enlace](https://www.analyticslane.com/2022/08/04/uso-de-multiples-ejes-en-matplotlib/). La idea es obtener algo como esto:
#
# <img src="https://www.edureka.co/community/?qa=blob&qa_blobid=5104085296578093682" width="300">
#
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 7: Exportar y documentar resultados
#
# En esta etapa final consolidarás todo tu trabajo: guardarás el dataset limpio y crearás un resumen que documente los resultados del proyecto.
#
# ### 7.1 Guardar dataset final
#
# **🎯Objetivo:**
# Generar un CSV limpio, reproducible y con columnas relevantes para análisis posterior.
#
# **Instrucciones**
#
# - Exporta el DataFrame `merged` con el nombre: `ladb_mobility_economy_2024_clean.csv`
# - Usa `index=False` para no incluir el índice.

# %%
# Exporta el dataset final como CSV
merged.to_csv("ladb_mobility_economy_2024_clean.csv", index=False)

# %% [markdown]
# Para poder ver o descargar el archivo generado:
# En el menú lateral que esta a la izquierda, ve hasta la parte de abajo, a la sección de **Exportar dataset** para más información.

# %% [markdown]
# ---
#
# ## ✅ Entregables
#
# 1. **Notebook `.ipynb`** con todas las celdas (código + comentarios).
# 2. **CSV final**: `ladb_mobility_economy_2024_clean.csv`.
# 3. **Resumen ejecutivo breve** en Markdown (3–5 párrafos).

# %% [markdown]
# ---
#
# # 🧾 Resumen ejecutivo (plantilla)
#
# > Completa este resumen al finalizar el análisis. Mantén 3–5 párrafos cortos, claros y accionables.
#
# **Contexto & objetivo:**
# - Responde la pregunta central del análisis: ¿qué relación existe entre la movilidad urbana (congestión, tiempos de viaje) y la productividad económica (PIB per cápita)?
# la relación entre PIB per cápita y congestión no sigue un patrón lineal directo. Los datos revelan una situación multifactorial donde: No existe correlación directa simple: Ciudades con mayor PIB no necesariamente presentan más o menos congestión de manera consistente
# Factores adicionales influyen significativamente: Planificación urbana, infraestructura de transporte y políticas públicas
#
# - Explica brevemente las variables clave utilizadas y su relevancia para la toma de decisiones.
# Variables de Movilidad:
# jams_delay: Tiempo de retraso por congestión
# traffic_index_live: Índice de tráfico (0-100)
# travel_time_live_per_10kms_mins: Tiempo de viaje por 10km
#
# Variables Económicas:
# city_gdp_capita: PIB per cápita (productividad)
# unemployment_pct: Tasa de desempleo
# population: Población total
#
# Relevancia para Decisiones
# Para el banco de desarrollo:
# Priorizar inversiones donde alta congestión + bajo PIB = mayor impacto potencial
# Medir retorno relacionando mejoras de movilidad con crecimiento económico
# Optimizar recursos enfocándose en ciudades con mejor relación costo-beneficio
#
# **Cobertura de datos:**
# - Especifica los años analizados, número de ciudades y países incluidos.
# Año analizado: 2024 únicamente
# Número de ciudades: 30 ciudades latinoamericanas incluidas en el dataset final merged
# Países incluidos: 6 países de América Latina:
# Brasil: São Paulo, Río de Janeiro, Brasília, Salvador, Belo Horizonte, Curitiba
# Argentina: Buenos Aires
# Colombia: Bogotá
# México: Ciudad de México
# Perú: Lima
# Chile: Santiago
#
# **Metodología (alto nivel):**
# - Describe los procesos principales: limpieza de datos (formatos, estandarización de columnas).
# Estandarización: Conversión a snake_case
# Conversión de fechas: object → datetime64[ns] (columnas de tiempo)
# Extracción temporal: Creación de columna year desde update_time_utc
# Filtrado: Solo registros de 2024
# Agregación: Promedios por ciudad/país/año
# Limpieza numérica:
# city_gdp_capita: Eliminación de separadores (.) y cambio de comas por puntos
# unemployment_pct: Eliminación de % y cambio de comas por puntos
# pm25: Cambio de comas por puntos
# population_m: Cambio de comas por puntos
# Conversión de tipos: object → float64 (variables numéricas)
#
# - Explica la agregación por ciudad–año y el uso de una unión INNER para integrar tráfico y economía.
# Proceso de unión:
# merged = pd.merge(traffic_city_year_2024, eco_2024, on=['city', 'year'], how='inner')
# Tipo: INNER JOIN
# Claves: city, year
# Resultado: 30 ciudades latinoamericanas con datos completos de movilidad y economía para 2024
# Ventajas del INNER JOIN:
#
# Garantiza completitud: Todas las ciudades tienen datos de movilidad y económicos
# Elimina valores faltantes: No hay ciudades con información parcial
# Permite análisis correlacional: Cada observación tiene todas las variables necesarias
# Impacto: Se excluyen ciudades que solo aparecen en uno de los datasets, asegurando calidad analítica sobre cantidad de datos.
#
# - Menciona las validaciones visuales empleadas (distribuciones, outliers, tendencias generales).
# 1. Análisis de Distribuciones
# Boxplot para JamsDelay:
# Propósito: Analizar la distribución de los minutos de congestión
# Métricas visualizadas: Media, mediana, cuartiles y rango intercuartílico
# Hallazgos: Distribución con asimetría positiva marcada (promedio 630 min > mediana 263 min)
# Histograma para PIB per cápita:
# Propósito: Examinar la forma de distribución de la productividad económica
# Análisis: Frecuencia y concentración de valores del PIB per cápita entre ciudades
#
# 2. Detección de Outliers
# Identificación sistemática:
# Método: Regla del rango intercuartílico (IQR)
# Fórmula aplicada: Límite superior = Q3 + 1.5 × (Q3 - Q1)
# Resultado: Ciudades con congestión extrema (>1,942 minutos) identificadas como valores atípicos
#
# 3. Análisis de Tendencias Generales
# Gráfico de barras comparativo:
# Variables: JamsDelay vs City_GDP_capita por ciudad
# Objetivo: Visualizar relaciones entre congestión y productividad económica
# Configuración: Rotación de etiquetas (90°) para mejor legibilidad
#
# 4. Validaciones Estadísticas Complementarias
# Estadísticas descriptivas visualizadas:
# Rango de valores: Mínimo, máximo y cuartiles
# Medidas de tendencia central: Media y mediana mostradas en boxplot
# Variabilidad: Identificación de alta dispersión en datos de tráfico
#
# **Hallazgos iniciales:**
# - Resume los patrones más importantes entre índices de tráfico y PIB per cápita.
# 1. Relación No Lineal Compleja
# La relación entre PIB per cápita y congestión no sigue un patrón directo simple. Los datos revelan que ciudades con mayor productividad económica no necesariamente presentan más o menos congestión de manera consistente.
# 2. Casos Específicos Destacados
# Bogotá (Colombia): PIB $114,420 con alta congestión (1,141 minutos de retraso promedio)
# Buenos Aires (Argentina): PIB $181,170 con congestión moderada-alta (571 minutos)
# Brasília (Brasil): PIB $162,510 con baja congestión (101 minutos)
# Distribución Asimétrica del Tráfico
# El análisis mostró una distribución con asimetría positiva marcada en los datos de congestión:
# Promedio: 630 minutos de retraso
# Mediana: 263 minutos
# 50% de las ciudades: Entre 107 y 841 minutos de retraso diario
# Valores atípicos: Ciudades con más de 1,942 minutos (congestión extrema)
#
# - Destaca anomalías u outliers que podrían requerir revisión adicional o un análisis más profundo.
# 1. Ciudad de México - Anomalía de Prosperidad vs. Congestión Extrema
# PIB per cápita: $211,110 (el más alto del grupo)
# Congestión: 2,833 minutos (la más alta registrada)
# Anomalía: Paradoja económica - mayor prosperidad coincide con mayor congestión
# 2. São Paulo - Congestión Desproporcionada
# PIB per cápita: $147,030 (segundo más alto)
# Congestión: 1,729 minutos (segunda más alta)
# Anomalía: Congestión muy alta para su nivel económico intermedio
# 3. Bogotá - Inversión de la Relación Esperada
# PIB per cápita: $114,420 (el más bajo del grupo)
# Congestión: 1,141 minutos (alta, pero menor que las anteriores)
# Anomalía: Congestión alta con productividad económica relativamente baja
# 4. Lima - Patrón Intermedio Consistente
# PIB per cápita: $134,720 (medio-alto)
# Congestión: 1,052 minutos (alta)
#
# **Recomendaciones**
# Aterriza los hallazgos en acciones: ciudades prioritarias, necesidad de validar fuentes, requerimiento de análisis adicionales, o propuestas de inversión.
# Ciudad de México: Investigar si la alta congestión limita el crecimiento económico potencial
# Bogotá: Evaluar como candidata prioritaria - mayor retorno de inversión esperado (baja productividad + alta congestión)
# São Paulo: Validar metodología de medición y factores de planificación urbana
#
# - ¿Qué ciudad : Bogotá, Lima o Buenos Aires o alguna otra en particular, muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica, sugiriendo ser una ciudad prioritaria para inversión en infraestructura de transporte?
# Bogotá es la ciudad que muestra la mayor correlación significativa entre altos niveles de congestión vehicular y bajos indicadores de productividad económica.
# Análisis Comparativo de las Ciudades Mencionadas:
# Bogotá (Colombia):
# PIB per cápita: $114,420 (el más bajo entre las ciudades analizadas)
# Congestión promedio: 1,141 minutos de retraso diario
# Ratio congestión/productividad: Muy desfavorable
# Lima (Perú):
# PIB per cápita: $134,720 (intermedio)
# Congestión promedio: 1,052 minutos de retraso diario
# Ratio congestión/productividad: Moderadamente desfavorable
# Buenos Aires (Argentina):
# PIB per cápita: $181,170 (alto)
# Congestión promedio: 571 minutos de retraso diario
# Ratio congestión/productividad: Relativamente favorable
#
# ¿Por qué Bogotá es prioritaria?
# Mayor potencial de retorno de inversión: Combina la productividad económica más baja con niveles altos de congestión
# Impacto económico esperado: Las mejoras en movilidad podrían generar aumentos significativos en la productividad
# Urgencia social: La alta congestión con baja productividad sugiere que los problemas de transporte están limitando el desarrollo económico

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor (1ra Iteración)</b> <a class=“tocSkip”></a>
#
# Tu resumen conecta bien el objetivo del banco con las variables de movilidad y economía, y plantea una lectura razonable sobre una relación no lineal entre productividad y congestión, además de aterrizar recomendaciones de priorización por ciudad.
#
# Ten en cuenta que afirmas “correlación significativa” sin mostrar una métrica (correlación, regresión o prueba).
#
# En futuros análisis, apóyate en un indicador cuantitativo (correlación y/o un scatter con línea de tendencia
#
# </div>
